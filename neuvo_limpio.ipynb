# %%
from IPython.display import display, Markdown

import pandas as pd
import gc
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.pipeline import make_pipeline

from sklearn.model_selection import RandomizedSearchCV, train_test_split, KFold, cross_val_score

from sklearn.metrics import roc_auc_score

from hyperopt import hp, fmin, tpe, Trials, STATUS_OK, space_eval

from sklearn.tree import plot_tree

from sklearn.preprocessing import LabelEncoder, PolynomialFeatures, StandardScaler, OneHotEncoder

from scipy.sparse import hstack

# XGBoost
import xgboost as xgb
import numpy as np
import matplotlib.pyplot as plt
import itertools
from scipy.stats import uniform
import pandas as pd # Para cargar los datos y hacer OHE.
import numpy as np  # Para lidiar con NaNs.
import time
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score, roc_auc_score, make_scorer
from sklearn.model_selection import ParameterSampler
from sklearn.metrics import confusion_matrix


#w2v
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import nltk
import re
import logging
import gensim
import numpy as np
import random
import os
import pickle
import tqdm
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

random_state = 42
np.random.seed(random_state)

# %% [markdown]
# ## Cargo los datos

# %%
# Load the competition data
comp_data = pd.read_csv("./competition_data.csv")

# %% [markdown]
# ## Tuneo de datos

# %% [markdown]
# Retoque de fecha

# %%
comp_data['date'] = pd.to_datetime(comp_data['date'])
comp_data['month'] = comp_data['date'].dt.month
# comp_data['day'] = comp_data['date'].dt.day
comp_data['dayofweek'] = comp_data['date'].dt.dayofweek
# comp_data['hour'] = comp_data['date'].dt.hour

# %% [markdown]
# OHE en las categoricas

# %%
comp_data['is_pdp'].fillna(-1, inplace=True)
comp_data = pd.get_dummies(comp_data, columns=['is_pdp'], prefix='is_pdp')
comp_data = pd.get_dummies(comp_data, columns=['listing_type_id','logistic_type','platform','month','dayofweek']) #hour

# %% [markdown]
# W2Vec en title

# %%
# Descarga de stopwords para español si no están descargadas ya
nltk.download('stopwords')

STOP_WORDS_SP = set(stopwords.words('spanish'))

def iterate_LN_corpus(path):
    """
    Genera un iterador para recorrer los archivos de texto en un directorio.

    Args:
        path (str): Ruta al directorio que contiene los archivos.

    Yields:
        str: Texto contenido en cada archivo.
    """
    articles = os.listdir(path)
    random.shuffle(articles)
    for art in articles:
        with open(path + art, encoding="utf-8") as f:
            raw_text = f.read()
        yield(raw_text)

def tokenizer(raw_text):
    """
    Tokeniza y preprocesa un texto.

    Args:
        raw_text (str): Texto sin procesar.

    Returns:
        list: Lista de oraciones, donde cada oración es una lista de palabras.
    """
    sentences = sent_tokenize(raw_text)
    sentences = [word_tokenize(e) for e in sentences]
    sentences = [[e2 for e2 in e1 if re.compile("[A-Za-z]").search(e2[0])] for e1 in sentences]
    sentences = [[e2.lower() for e2 in e1] for e1 in sentences]
    return(sentences)

def gen_sentences(path):
    """
    Genera una lista de oraciones a partir de archivos de texto en un directorio.

    Args:
        path (str): Ruta al directorio que contiene los archivos de texto.

    Returns:
        list: Lista de oraciones.
    """
    sentences = []
    n_arts = len(os.listdir(path))
    for i, art in tqdm.tqdm(enumerate(iterate_LN_corpus(path)), total=n_arts):
        sentences.extend(tokenizer(art))
    return(sentences)

def average_vectors(title_tokens, model, stopwords=None):
    """
    Calcula el vector promedio de un conjunto de tokens utilizando un modelo Word2Vec.

    Args:
        title_tokens (list): Lista de tokens.
        model (gensim.models.Word2Vec): Modelo Word2Vec.
        stopwords (set, optional): Conjunto de palabras stopwords. Defaults to None.

    Returns:
        numpy.ndarray: Vector promedio.
    """
    title_tokens = [e2 for e1 in title_tokens for e2 in e1]
    title_tokens = [e for e in title_tokens if e in model.wv]
    if stopwords is not None:
        title_tokens = [e for e in title_tokens if e not in stopwords]
    if len(title_tokens) == 0:
        output = np.zeros(model.wv.vector_size)
    else:
        output = np.array([model.wv.get_vector(e) for e in title_tokens]).mean(0)
    return output

def dummy_tokenizer(text_tokens):
    """
    Tokenizador dummy que simplemente devuelve los tokens de texto sin procesar.

    Args:
        text_tokens (list): Lista de tokens.

    Returns:
        list: Misma lista de tokens de entrada.
    """
    return text_tokens

# Configuración básica del logging
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s",
                    datefmt= '%H:%M:%S', level=logging.INFO)


#~ Análisis con datos de; TP ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

# Carga de datos desde un archivo CSV
# comp_data = pd.read_csv("competition_data.csv")
comp_data["title_tokens"] = comp_data["title"].map(tokenizer)

# Creación del modelo Word2Vec
w2v_tp = gensim.models.Word2Vec(vector_size=300,
                                window=3,
                                min_count=5,
                                negative=15,
                                sample=0.01,
                                workers=8,
                                sg=1)

# Creación del vocabulario a partir del corpus
w2v_tp.build_vocab([e2 for e1 in comp_data["title_tokens"].values for e2 in e1],
                   progress_per=10000)

# Entrenamiento del modelo Word2Vec
w2v_tp.train([e2 for e1 in comp_data["title_tokens"].values for e2 in e1],
             total_examples=w2v_tp.corpus_count,
             epochs=30, report_delay=1)

## Ejercicio de predicción con word2vec

# Obtención de embeddings de títulos utilizando el modelo Word2Vec
title_embs = comp_data["title_tokens"].map(lambda x: average_vectors(x, w2v_tp, STOP_WORDS_SP))
title_embs= np.array(title_embs.to_list())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lucaspinera/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/g9/vvg7d46s4kz8pqxxfcx8tjt00000gn/T/ipykernel_8247/2404927379.py in <module>
#      96 # Carga de datos desde un archivo CSV
#      97 # comp_data = pd.read_csv("competition_data.csv")
# ---> 98 comp_data["title_tokens"] = comp_data["title"].map(tokenizer)
#      99
#     100 # Creación del modelo Word2Vec
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    4235         dtype: object
#    4236         """
# -> 4237         new_values = self._map_values(arg, na_action=na_action)
#    4238         return self._constructor(new_values, index=self.index).__finalize__(
#    4239             self, method="map"
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     878
#     879         # mapper is a function
# --> 880         new_values = map_f(values, mapper)
#     881
#     882         return new_values
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/g9/vvg7d46s4kz8pqxxfcx8tjt00000gn/T/ipykernel_8247/2404927379.py in tokenizer(raw_text)
#      31         list: Lista de oraciones, donde cada oración es una lista de palabras.
#      32     """
# ---> 33     sentences = sent_tokenize(raw_text)
#      34     sentences = [word_tokenize(e) for e in sentences]
#      35     sentences = [[e2 for e2 in e1 if re.compile("[A-Za-z]").search(e2[0])] for e1 in sentences]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#     108
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     748
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#     752     if format == "raw":
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in _open(resource_url)
#     874
#     875     if protocol is None or protocol.lower() == "nltk":
# --> 876         return find(path_, path + [""]).open()
#     877     elif protocol.lower() == "file":
#     878         # urllib might not use mode='rb', so handle this one ourselves:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/Users/lucaspinera/nltk_data'
#     - '/Users/lucaspinera/opt/anaconda3/nltk_data'
#     - '/Users/lucaspinera/opt/anaconda3/share/nltk_data'
#     - '/Users/lucaspinera/opt/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
title_embs_df = pd.DataFrame(title_embs, columns=[f"emb_{i}" for i in range(title_embs.shape[1])])

# Concatenate comp_data with title_embs_df along the columns axis (axis=1)
comp_data = pd.concat([comp_data, title_embs_df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/g9/vvg7d46s4kz8pqxxfcx8tjt00000gn/T/ipykernel_8247/2190621255.py in <module>
# ----> 1 title_embs_df = pd.DataFrame(title_embs, columns=[f"emb_{i}" for i in range(title_embs.shape[1])])
#       2
#       3 # Concatenate comp_data with title_embs_df along the columns axis (axis=1)
#       4 comp_data = pd.concat([comp_data, title_embs_df], axis=1)
#
# NameError: name 'title_embs' is not defined

# %%
comp_data.dtypes
# comp_data['emb_299']
# Out:
# accepts_mercadopago              bool
# available_quantity              int64
# avg_gmv_item_domain_30days    float64
# avg_gmv_item_sel              float64
# avg_gmv_seller_bday           float64
#                                ...
# emb_295                       float64
# emb_296                       float64
# emb_297                       float64
# emb_298                       float64
# emb_299                       float64
# Length: 379, dtype: object

# %% [markdown]
# Dropeo los que no ayudan al modelo

# %%
comp_data = comp_data.drop(
    columns=['accepts_mercadopago', 
            # 'available_quantity',
            # 'avg_gmv_item_domain_30days',
            # 'avg_gmv_item_sel',
            # 'avg_gmv_seller_bday',
            # 'avg_qty_orders_item_domain_30days',
            # 'avg_qty_orders_item_sel_30days',
            # 'avg_si_item_sel_30day',
            'benefit',              
            'boosted',
            'category_id',          
            # 'conversion',
            'date',             #chiche d efechas separar dia mes etc
            'deal_print_id',
            'domain_id',
            'etl_version',
            'free_shipping',    
            'fulfillment',
            'full_name',
            # 'health',
            # 'is_pdp',
            'product_id',
            'item_id',
            # 'listing_type_id', #hacer OHE
            # 'logistic_type',   #hacer OHE
            'main_picture',
            # 'offset',
            # 'original_price',
            # 'platform',        #hacer OHE
            # 'price',
            # 'print_position',
            'print_server_timestamp',
            # 'qty_items_dom',
            # 'qty_items_sel',
            'site_id',
            # 'sold_quantity',
            'tags',             #experimentar
            'title',            #W2vec
            # 'total_asp_item_domain_30days',
            # 'total_asp_item_sel_30days',
            # 'total_gmv_domain_bday',
            # 'total_gmv_item_30days',
            # 'total_items_domain',
            # 'total_items_seller',
            # 'total_orders_domain_30days',
            # 'total_orders_item_30days',
            # 'total_orders_sel_30days',
            # 'total_si_domain_30days',
            # 'total_si_item_30days',
            # 'total_si_sel_30days',
            # 'total_visits_domain',
            # 'total_visits_item',
            # 'total_visits_seller',
            'uid',
            'user_id',
            'warranty',
            # 'ROW_ID',
            'title_tokens'
            ]
)

# %% [markdown]
# ## Validation Set - HOLDOUT SET

# %%
# Split into training and evaluation samples
train_data = comp_data[comp_data["ROW_ID"].isna()]
eval_data = comp_data[comp_data["ROW_ID"].notna()]
del comp_data
gc.collect()

y_train_all = train_data["conversion"]
X_train_all = train_data.drop(columns=["conversion", "ROW_ID"])
# X_train_all = X_train_all.select_dtypes(include='number') 
del train_data
gc.collect()

#hold out set
X_train, X_val, y_train, y_val = train_test_split(X_train_all, y_train_all, test_size=0.2, random_state=random_state)

# %%
X_train.dtypes
# Out:
# available_quantity                     int64
# avg_gmv_item_domain_30days           float64
# avg_gmv_item_sel                     float64
# avg_gmv_seller_bday                  float64
# avg_qty_orders_item_domain_30days    float64
#                                       ...
# emb_295                              float64
# emb_296                              float64
# emb_297                              float64
# emb_298                              float64
# emb_299                              float64
# Length: 355, dtype: object

# %% [markdown]
# ## Modelo de aprendizaje - XGBoost

# %%
#ver uan forma de tener mejor parametos que gerar
params = {'max_depth': list(range(3, 12)),
          'learning_rate': uniform(scale = 0.03),
          'gamma': uniform(scale=15),               #chiche va de 1 a 20
          'reg_lambda': uniform(scale = 15),        # Parámetro de regularización.
          'subsample': uniform(0.5, 0.5),          # Entre 0.5 y 1.
          'min_child_weight': uniform(scale = 50),   #0 a 100
          'colsample_bytree': uniform(0.65, 0.35), # Entre 0.75 y 1.
          'n_estimators': list(range(500, 2500))    #ma que 500 tambein a la noche para que corra
         }

l_auc = []
l_grid = []
start = time.time()
best_score = 0
best_estimator = None
iterations = 300
for g in ParameterSampler(params, n_iter = iterations, random_state = random_state):
    clf_xgb = xgb.XGBClassifier(objective = 'binary:logistic', seed = random_state, eval_metric = 'auc', **g, tree_method = 'gpu_hist') #enable_categorical = True
    clf_xgb.fit(X_train, y_train, eval_set = [(X_val, y_val)], verbose = False)

    y_pred = clf_xgb.predict_proba(X_val)[:, 1] # Obtenemos la probabilidad de una de las clases (cualquiera).
    auc_roc = sklearn.metrics.roc_auc_score(y_val, y_pred)
    
    l_auc.append(auc_roc)
    l_grid.append(g)
    print(f'Roc-AUC actual; {auc_roc}')
    print(f'Con grid: {g}')
    # Guardamos si es mejor.
    if auc_roc > best_score:
        print('-'*10)
        print(f'Mejor valor de ROC-AUC encontrado: {auc_roc}')
        print(f'Grid{g}')
        print('-'*10)
        best_score = auc_roc
        best_grid = g
        best_estimator = clf_xgb

end = time.time()

df_aux = pd.DataFrame({'auc': l_auc, 'grid': l_grid})
df_aux.to_csv('grid_search.csv', index = False)
# Out:
# Roc-AUC actual; 0.8871928067599784
# Con grid: {'colsample_bytree': 0.7810890415965769, 'gamma': 14.260714596148743, 'learning_rate': 0.02195981825434215, 'max_depth': 7, 'min_child_weight': 7.800932022121826, 'n_estimators': 966, 'reg_lambda': 1.4996237372700434, 'subsample': 0.7296244459829335}
# ----------
# Mejor valor de ROC-AUC encontrado: 0.8871928067599784
# Grid{'colsample_bytree': 0.7810890415965769, 'gamma': 14.260714596148743, 'learning_rate': 0.02195981825434215, 'max_depth': 7, 'min_child_weight': 7.800932022121826, 'n_estimators': 966, 'reg_lambda': 1.4996237372700434, 'subsample': 0.7296244459829335}
# ----------
# Roc-AUC actual; 0.8962174210240451
# Con grid: {'colsample_bytree': 0.7667980138986576, 'gamma': 2.143002268829112, 'learning_rate': 0.019526654188465584, 'max_depth': 7, 'min_child_weight': 48.49549260809972, 'n_estimators': 2015, 'reg_lambda': 14.078290635236252, 'subsample': 0.5003893829205072}
# ----------
# Mejor valor de ROC-AUC encontrado: 0.8962174210240451
# Grid{'colsample_bytree': 0.7667980138986576, 'gamma': 2.143002268829112, 'learning_rate': 0.019526654188465584, 'max_depth': 7, 'min_child_weight': 48.49549260809972, 'n_estimators': 2015, 'reg_lambda': 14.078290635236252, 'subsample': 0.5003893829205072}
# ----------
# Roc-AUC actual; 0.8932359658156197
# Con grid: {'colsample_bytree': 0.9972740457519261, 'gamma': 9.262222644415749, 'learning_rate': 0.018349594814648425, 'max_depth': 11, 'min_child_weight': 14.561457009902096, 'n_estimators': 1582, 'reg_lambda': 5.997914575728832, 'subsample': 0.5233328316068078}
# Roc-AUC actual; 0.8803256628872211
# Con grid: {'colsample_bytree': 0.9908144315945107, 'gamma': 3.4915701064545637, 'learning_rate': 0.002718193035984624, 'max_depth': 5, 'min_child_weight': 19.12309956335814, 'n_estimators': 1767, 'reg_lambda': 8.886218532930638, 'subsample': 0.5232252063599989}
# Roc-AUC actual; 0.872739970397584
# Con grid: {'colsample_bytree': 0.8626406981655035, 'gamma': 2.557861855309373, 'learning_rate': 0.0019515477895583853, 'max_depth': 6, 'min_child_weight': 47.11008778424264, 'n_estimators': 513, 'reg_lambda': 12.125960221746917, 'subsample': 0.6523068845866853}
# Roc-AUC actual; 0.8895541584459242
# Con grid: {'colsample_bytree': 0.6841852399022343, 'gamma': 10.263495397682354, 'learning_rate': 0.01320457481218804, 'max_depth': 9, 'min_child_weight': 30.499832889131046, 'n_estimators': 1275, 'reg_lambda': 0.5158278167282759, 'subsample': 0.954660201039391}
# Roc-AUC actual; 0.8894027616211982
# Con grid: {'colsample_bytree': 0.7405729935600059, 'gamma': 9.93783426530973, 'learning_rate': 0.009351332282682328, 'max_depth': 8, 'min_child_weight': 10.397083143409441, 'n_estimators': 2295, 'reg_lambda': 2.7728168328829055, 'subsample': 0.9847923138822793}
# Roc-AUC actual; 0.8876920099875177
# Con grid: {'colsample_bytree': 0.9212964881763901, 'gamma': 14.092484123462837, 'learning_rate': 0.026844820512829465, 'max_depth': 10, 'min_child_weight': 28.52219872026997, 'n_estimators': 1775, 'reg_lambda': 0.678409333658071, 'subsample': 0.6626651653816322}
# Roc-AUC actual; 0.8963774510412101
# Con grid: {'colsample_bytree': 0.7860370513913187, 'gamma': 4.070235476608438, 'learning_rate': 0.02486212527455788, 'max_depth': 11, 'min_child_weight': 14.046725484369038, 'n_estimators': 879, 'reg_lambda': 4.1399877303381505, 'subsample': 0.6481367528520412}
# ----------
# Mejor valor de ROC-AUC encontrado: 0.8963774510412101
# Grid{'colsample_bytree': 0.7860370513913187, 'gamma': 4.070235476608438, 'learning_rate': 0.02486212527455788, 'max_depth': 11, 'min_child_weight': 14.046725484369038, 'n_estimators': 879, 'reg_lambda': 4.1399877303381505, 'subsample': 0.6481367528520412}
# ----------
# Roc-AUC actual; 0.8877799350474203
# Con grid: {'colsample_bytree': 0.7078434286720509, 'gamma': 0.23454610111790897, 'learning_rate': 0.012702044421191088, 'max_depth': 3, 'min_child_weight': 9.93578407670862, 'n_estimators': 1995, 'reg_lambda': 0.21119734072626684, 'subsample': 0.5994212020444025}
# Roc-AUC actual; 0.8881429607894817
# Con grid: {'colsample_bytree': 0.8989696834620275, 'gamma': 11.852633107968085, 'learning_rate': 0.01817879924343034, 'max_depth': 9, 'min_child_weight': 32.55385127509722, 'n_estimators': 1551, 'reg_lambda': 12.946551388133903, 'subsample': 0.811649063413779}
# Roc-AUC actual; 0.895606097547278
# Con grid: {'colsample_bytree': 0.7658143086984273, 'gamma': 0.9533752542903545, 'learning_rate': 0.009329469651469866, 'max_depth': 10, 'min_child_weight': 33.296117830874834, 'n_estimators': 1183, 'reg_lambda': 9.563362070328196, 'subsample': 0.9436063712881633}
# Roc-AUC actual; 0.8856288683488528
# Con grid: {'colsample_bytree': 0.8152752238066823, 'gamma': 1.7939136890745255, 'learning_rate': 0.021397343616689848, 'max_depth': 3, 'min_child_weight': 36.08647605824366, 'n_estimators': 1002, 'reg_lambda': 11.564507699318415, 'subsample': 0.7468977981821954}
# Roc-AUC actual; 0.8703959473979052
# Con grid: {'colsample_bytree': 0.8329564902836979, 'gamma': 6.413115275378244, 'learning_rate': 0.0007625738023228556, 'max_depth': 5, 'min_child_weight': 1.5714592843367126, 'n_estimators': 1242, 'reg_lambda': 7.130553347731676, 'subsample': 0.7816377859881918}
# Roc-AUC actual; 0.8960156223758322
# Con grid: {'colsample_bytree': 0.8934306302491446, 'gamma': 2.089971816088135, 'learning_rate': 0.018132521378334515, 'max_depth': 6, 'min_child_weight': 47.14267852789905, 'n_estimators': 2362, 'reg_lambda': 4.346271793706521, 'subsample': 0.5806106436270022}
# Roc-AUC actual; 0.888045708321666
# Con grid: {'colsample_bytree': 0.9753941783199005, 'gamma': 12.121805693466253, 'learning_rate': 0.019002112695312705, 'max_depth': 8, 'min_child_weight': 22.826728524145512, 'n_estimators': 2143, 'reg_lambda': 2.7985508832905377, 'subsample': 0.9462794992449889}
# Roc-AUC actual; 0.8887879937676538
# Con grid: {'colsample_bytree': 0.8387697846704778, 'gamma': 12.111602327460938, 'learning_rate': 0.026882738997704797, 'max_depth': 9, 'min_child_weight': 45.3414220772877, 'n_estimators': 1908, 'reg_lambda': 3.4190274381291252, 'subsample': 0.7135538943131281}
# Roc-AUC actual; 0.8725776263288375
# Con grid: {'colsample_bytree': 0.9363051680728727, 'gamma': 12.910958748845152, 'learning_rate': 0.00020856391593572108, 'max_depth': 10, 'min_child_weight': 26.7044709687721, 'n_estimators': 817, 'reg_lambda': 3.3316171570609536, 'subsample': 0.5599326836668415}
# Roc-AUC actual; 0.8867272907833479
# Con grid: {'colsample_bytree': 0.7681653099912698, 'gamma': 14.143645558687787, 'learning_rate': 0.009696087960622657, 'max_depth': 10, 'min_child_weight': 35.15094794475889, 'n_estimators': 1636, 'reg_lambda': 0.9733837066347234, 'subsample': 0.6269577069671723}
# Roc-AUC actual; 0.8882077364333697
# Con grid: {'colsample_bytree': 0.7364066219935105, 'gamma': 10.444564092596826, 'learning_rate': 0.02136811769773326, 'max_depth': 7, 'min_child_weight': 14.242024718873381, 'n_estimators': 1604, 'reg_lambda': 4.001715214129275, 'subsample': 0.9883074779163264}
# Roc-AUC actual; 0.8840904201059184
# Con grid: {'colsample_bytree': 0.7938629546613809, 'gamma': 0.4957609935082258, 'learning_rate': 0.010352137440800489, 'max_depth': 3, 'min_child_weight': 11.97809453334862, 'n_estimators': 1653, 'reg_lambda': 7.964018749757046, 'subsample': 0.7238915822865458}
# Roc-AUC actual; 0.8843006516921066
# Con grid: {'colsample_bytree': 0.8435125811749649, 'gamma': 8.890450858190903, 'learning_rate': 0.0024255997899814575, 'max_depth': 10, 'min_child_weight': 11.881877199619984, 'n_estimators': 1266, 'reg_lambda': 12.047096345698439, 'subsample': 0.7351503172230192}
# Roc-AUC actual; 0.8839654123694209
# Con grid: {'colsample_bytree': 0.994198099313195, 'gamma': 5.982366636668296, 'learning_rate': 0.024492956196581518, 'max_depth': 3, 'min_child_weight': 7.535877198271473, 'n_estimators': 686, 'reg_lambda': 2.7977776559978134, 'subsample': 0.520387570777382}
# Roc-AUC actual; 0.8698747651304397
# Con grid: {'colsample_bytree': 0.8568125301158847, 'gamma': 10.163465427634236, 'learning_rate': 0.0004976348678356846, 'max_depth': 5, 'min_child_weight': 40.47505230698577, 'n_estimators': 1671, 'reg_lambda': 9.677591856141747, 'subsample': 0.5871832145024958}
# Roc-AUC actual; 0.8883774098154913
# Con grid: {'colsample_bytree': 0.8918282083358631, 'gamma': 5.801030194508061, 'learning_rate': 0.028101899662102036, 'max_depth': 3, 'min_child_weight': 33.784505851964035, 'n_estimators': 2476, 'reg_lambda': 1.702102818608836, 'subsample': 0.9623468091392814}
# Roc-AUC actual; 0.8957941142382828
# Con grid: {'colsample_bytree': 0.9570687736833434, 'gamma': 3.869124415727334, 'learning_rate': 0.01979952138102537, 'max_depth': 11, 'min_child_weight': 25.831794563550716, 'n_estimators': 1380, 'reg_lambda': 3.627784363506775, 'subsample': 0.5465513839029497}
# Roc-AUC actual; 0.8870481162347397
# Con grid: {'colsample_bytree': 0.9640255152836643, 'gamma': 13.506270857449957, 'learning_rate': 0.018993043718198037, 'max_depth': 11, 'min_child_weight': 13.943567629609094, 'n_estimators': 2182, 'reg_lambda': 10.889335183053591, 'subsample': 0.9485551299762885}
# Roc-AUC actual; 0.8853441109514396
# Con grid: {'colsample_bytree': 0.960480248492791, 'gamma': 11.698133187864357, 'learning_rate': 0.01926094938462863, 'max_depth': 3, 'min_child_weight': 8.081435704730689, 'n_estimators': 1945, 'reg_lambda': 10.034823820713429, 'subsample': 0.7903433107182274}
# Roc-AUC actual; 0.8844113657099885
# Con grid: {'colsample_bytree': 0.7802989682966102, 'gamma': 14.102001636866676, 'learning_rate': 0.02920991510265952, 'max_depth': 4, 'min_child_weight': 8.040402570874933, 'n_estimators': 837, 'reg_lambda': 7.284206303793399, 'subsample': 0.7242120714931237}
# Roc-AUC actual; 0.875146463889768
# Con grid: {'colsample_bytree': 0.9980601119137873, 'gamma': 2.638878790160181, 'learning_rate': 0.000542260908465626, 'max_depth': 7, 'min_child_weight': 8.941135461066441, 'n_estimators': 2027, 'reg_lambda': 9.74449348570822, 'subsample': 0.924611705247089}
# Roc-AUC actual; 0.8786400142631019
# Con grid: {'colsample_bytree': 0.8801645123051202, 'gamma': 8.524629050032074, 'learning_rate': 0.002810243034842774, 'max_depth': 5, 'min_child_weight': 31.81663090929477, 'n_estimators': 1545, 'reg_lambda': 3.659844650686254, 'subsample': 0.9865052773762228}
# Roc-AUC actual; 0.8855556775673864
# Con grid: {'colsample_bytree': 0.7875842036333661, 'gamma': 13.380698327656699, 'learning_rate': 0.018934158779917887, 'max_depth': 4, 'min_child_weight': 17.503920384733785, 'n_estimators': 2132, 'reg_lambda': 8.653558269395386, 'subsample': 0.746258846909432}
# Roc-AUC actual; 0.8856295670144265
# Con grid: {'colsample_bytree': 0.7183350457293156, 'gamma': 10.83678172892258, 'learning_rate': 0.008423170873225673, 'max_depth': 5, 'min_child_weight': 38.42770071531545, 'n_estimators': 2035, 'reg_lambda': 2.6566601911057344, 'subsample': 0.9702292921764571}
# Roc-AUC actual; 0.8866171775288574
# Con grid: {'colsample_bytree': 0.9838750019509056, 'gamma': 13.722965853306729, 'learning_rate': 0.011104761007663331, 'max_depth': 11, 'min_child_weight': 47.65359235119766, 'n_estimators': 1872, 'reg_lambda': 6.422762224759715, 'subsample': 0.9833274095218347}
# Roc-AUC actual; 0.8879592784950933
# Con grid: {'colsample_bytree': 0.9872669919812385, 'gamma': 12.795141832010401, 'learning_rate': 0.00883346676208757, 'max_depth': 7, 'min_child_weight': 9.545551557517301, 'n_estimators': 1684, 'reg_lambda': 4.753830077344165, 'subsample': 0.5847463733430462}
# Roc-AUC actual; 0.8865211621886179
# Con grid: {'colsample_bytree': 0.8448804418604225, 'gamma': 14.042321612411715, 'learning_rate': 0.02088089390024919, 'max_depth': 10, 'min_child_weight': 3.520806542477195, 'n_estimators': 1125, 'reg_lambda': 9.225108400487546, 'subsample': 0.9950269250521316}
# Roc-AUC actual; 0.8898577931641243
# Con grid: {'colsample_bytree': 0.6990294053327835, 'gamma': 7.774944785456051, 'learning_rate': 0.026321192157838662, 'max_depth': 3, 'min_child_weight': 42.43348974623372, 'n_estimators': 1916, 'reg_lambda': 10.53726125980664, 'subsample': 0.6797455756098776}
# Roc-AUC actual; 0.8882165921307685
# Con grid: {'colsample_bytree': 0.7527571454925727, 'gamma': 12.140417332177705, 'learning_rate': 0.02430340184037542, 'max_depth': 11, 'min_child_weight': 30.575685543284024, 'n_estimators': 1327, 'reg_lambda': 7.670135982914067, 'subsample': 0.7507581473435998}
# Roc-AUC actual; 0.8898980977125369
# Con grid: {'colsample_bytree': 0.9294033126383713, 'gamma': 9.749458961666477, 'learning_rate': 0.0210590063177311, 'max_depth': 5, 'min_child_weight': 16.89975784257679, 'n_estimators': 1615, 'reg_lambda': 8.68297343261338, 'subsample': 0.7192370615090435}
# Roc-AUC actual; 0.8925817300323114
# Con grid: {'colsample_bytree': 0.8852091473533198, 'gamma': 4.922290012120979, 'learning_rate': 0.004651248501832326, 'max_depth': 8, 'min_child_weight': 29.541663028450536, 'n_estimators': 1865, 'reg_lambda': 3.753770407737961, 'subsample': 0.5194173672147115}
# Roc-AUC actual; 0.8917530904114371
# Con grid: {'colsample_bytree': 0.7561429301356279, 'gamma': 8.056236407949832, 'learning_rate': 0.009799537253881226, 'max_depth': 10, 'min_child_weight': 38.499677654930544, 'n_estimators': 1503, 'reg_lambda': 14.478777455861547, 'subsample': 0.7286325808068643}
# Roc-AUC actual; 0.893394932259077
# Con grid: {'colsample_bytree': 0.9447080762541935, 'gamma': 2.9157005099230955, 'learning_rate': 0.012340617151700357, 'max_depth': 5, 'min_child_weight': 31.871495074910328, 'n_estimators': 2343, 'reg_lambda': 1.9911813336445472, 'subsample': 0.9847684335570794}
# Roc-AUC actual; 0.8949515947580181
# Con grid: {'colsample_bytree': 0.9001082864629832, 'gamma': 0.6160127515181368, 'learning_rate': 0.011964627043343836, 'max_depth': 5, 'min_child_weight': 21.948571035281805, 'n_estimators': 2474, 'reg_lambda': 3.762907910199918, 'subsample': 0.592166837165685}
# Roc-AUC actual; 0.8857406993416327
# Con grid: {'colsample_bytree': 0.6783055383160193, 'gamma': 6.424717124101616, 'learning_rate': 0.020654997022960992, 'max_depth': 3, 'min_child_weight': 8.664716003542289, 'n_estimators': 1012, 'reg_lambda': 6.635283445966566, 'subsample': 0.6198936795787016}
# Roc-AUC actual; 0.8890033963691071
# Con grid: {'colsample_bytree': 0.6828556515284522, 'gamma': 2.74298995660961, 'learning_rate': 0.02803841992019129, 'max_depth': 3, 'min_child_weight': 47.743264033159704, 'n_estimators': 1203, 'reg_lambda': 8.31531078767101, 'subsample': 0.8058603731171761}
# Roc-AUC actual; 0.8961959448453282
# Con grid: {'colsample_bytree': 0.7968600218497265, 'gamma': 3.715964842517362, 'learning_rate': 0.010679180359537847, 'max_depth': 7, 'min_child_weight': 6.008232390282108, 'n_estimators': 1808, 'reg_lambda': 1.7410896076037434, 'subsample': 0.5230013210108764}
# Roc-AUC actual; 0.8872955239496063
# Con grid: {'colsample_bytree': 0.6642550808116395, 'gamma': 12.831908760165108, 'learning_rate': 0.02110973578140071, 'max_depth': 7, 'min_child_weight': 23.673588539028284, 'n_estimators': 1812, 'reg_lambda': 6.9701071940941715, 'subsample': 0.8248868413213817}
# Roc-AUC actual; 0.8853196576563609
# Con grid: {'colsample_bytree': 0.6668206234689619, 'gamma': 14.237185973870789, 'learning_rate': 0.026600411618941427, 'max_depth': 6, 'min_child_weight': 18.73063073132356, 'n_estimators': 1261, 'reg_lambda': 14.001544621192245, 'subsample': 0.7505199419576296}
# Roc-AUC actual; 0.8894297158720246
# Con grid: {'colsample_bytree': 0.8387821069400219, 'gamma': 10.259456540972117, 'learning_rate': 0.018475534931697415, 'max_depth': 9, 'min_child_weight': 47.212579856258365, 'n_estimators': 1395, 'reg_lambda': 9.54605396169017, 'subsample': 0.9004746473411999}
# Roc-AUC actual; 0.8826819681606795
# Con grid: {'colsample_bytree': 0.8870089198340436, 'gamma': 8.600505625079, 'learning_rate': 0.0038550105970173052, 'max_depth': 5, 'min_child_weight': 41.03197378719777, 'n_estimators': 1791, 'reg_lambda': 5.791539567011614, 'subsample': 0.9805952819119571}
# Roc-AUC actual; 0.8714851358765697
# Con grid: {'colsample_bytree': 0.9668727246846223, 'gamma': 2.9368670218394466, 'learning_rate': 0.0020808390262549636, 'max_depth': 4, 'min_child_weight': 1.9481566155116814, 'n_estimators': 1253, 'reg_lambda': 10.245101601245352, 'subsample': 0.5355943242301144}
# Roc-AUC actual; 0.8694926262123338
# Con grid: {'colsample_bytree': 0.7616414706028165, 'gamma': 12.673129664541818, 'learning_rate': 0.000698158072074776, 'max_depth': 4, 'min_child_weight': 13.034726411795155, 'n_estimators': 2426, 'reg_lambda': 1.7724724143248438, 'subsample': 0.8483685826820753}
# Roc-AUC actual; 0.8866833772044879
# Con grid: {'colsample_bytree': 0.8701299963729594, 'gamma': 13.162080202905795, 'learning_rate': 0.022052131314116572, 'max_depth': 7, 'min_child_weight': 48.379027576012376, 'n_estimators': 1175, 'reg_lambda': 2.6615931566958424, 'subsample': 0.8753073758204292}
# Roc-AUC actual; 0.8792462379261912
# Con grid: {'colsample_bytree': 0.9323921587435424, 'gamma': 14.8575771300101, 'learning_rate': 0.012378530307342794, 'max_depth': 4, 'min_child_weight': 12.500822460805233, 'n_estimators': 595, 'reg_lambda': 5.112053103795268, 'subsample': 0.9653786628017824}
# Roc-AUC actual; 0.8949574733390552
# Con grid: {'colsample_bytree': 0.9504444631450542, 'gamma': 6.4349104106252755, 'learning_rate': 0.02252613203374492, 'max_depth': 11, 'min_child_weight': 11.911807620198973, 'n_estimators': 2321, 'reg_lambda': 13.5382936001935, 'subsample': 0.7526261862239285}
# Roc-AUC actual; 0.8872690681098896
# Con grid: {'colsample_bytree': 0.9392601131377096, 'gamma': 4.800744015459176, 'learning_rate': 0.026865696854886014, 'max_depth': 3, 'min_child_weight': 2.6742648373684452, 'n_estimators': 944, 'reg_lambda': 13.580729646288955, 'subsample': 0.5456433383930668}
# Roc-AUC actual; 0.8847715478386643
# Con grid: {'colsample_bytree': 0.7617597731566452, 'gamma': 14.250929505762073, 'learning_rate': 0.028518214408126682, 'max_depth': 5, 'min_child_weight': 24.65128288859025, 'n_estimators': 643, 'reg_lambda': 6.726682829674797, 'subsample': 0.6466053858490323}
# Roc-AUC actual; 0.8905505045050758
# Con grid: {'colsample_bytree': 0.7650325908794706, 'gamma': 10.087776841155577, 'learning_rate': 0.0225712358831304, 'max_depth': 9, 'min_child_weight': 39.064802523560125, 'n_estimators': 1562, 'reg_lambda': 1.3680915457303555, 'subsample': 0.7472101523512907}
# Roc-AUC actual; 0.8938836911038048
# Con grid: {'colsample_bytree': 0.6701455660058255, 'gamma': 8.242933234856032, 'learning_rate': 0.01324591504120131, 'max_depth': 9, 'min_child_weight': 27.295788508249448, 'n_estimators': 2366, 'reg_lambda': 1.7560052464140878, 'subsample': 0.5714958410264179}
# Roc-AUC actual; 0.8898674988304694
# Con grid: {'colsample_bytree': 0.9165287211011153, 'gamma': 9.273270949743916, 'learning_rate': 0.003033680283683707, 'max_depth': 9, 'min_child_weight': 21.304573752347057, 'n_estimators': 1691, 'reg_lambda': 1.091445095462903, 'subsample': 0.9109300296451781}
# Roc-AUC actual; 0.8797148333714647
# Con grid: {'colsample_bytree': 0.8971847795047737, 'gamma': 1.2202317096284965, 'learning_rate': 0.0025451314225557573, 'max_depth': 5, 'min_child_weight': 29.065270861339116, 'n_estimators': 1888, 'reg_lambda': 5.559632206003363, 'subsample': 0.9063997836287513}
# Roc-AUC actual; 0.8859710943272752
# Con grid: {'colsample_bytree': 0.9815370020843506, 'gamma': 14.790015957343064, 'learning_rate': 0.022601345557768247, 'max_depth': 8, 'min_child_weight': 35.40905977915999, 'n_estimators': 2310, 'reg_lambda': 11.657203738911551, 'subsample': 0.7792021248679025}
# Roc-AUC actual; 0.878205577779252
# Con grid: {'colsample_bytree': 0.7984777032364417, 'gamma': 13.595315776421039, 'learning_rate': 0.0033359244691845403, 'max_depth': 5, 'min_child_weight': 12.684108693656936, 'n_estimators': 1253, 'reg_lambda': 7.029909629911894, 'subsample': 0.5281516378409187}
# Roc-AUC actual; 0.8834971862823806
# Con grid: {'colsample_bytree': 0.6915862706938252, 'gamma': 1.7628937016565733, 'learning_rate': 0.019476309063481908, 'max_depth': 3, 'min_child_weight': 34.05197135484545, 'n_estimators': 847, 'reg_lambda': 14.43258822711813, 'subsample': 0.6874352897618521}
# Roc-AUC actual; 0.8849043031978608
# Con grid: {'colsample_bytree': 0.7499992301986513, 'gamma': 13.028986922841904, 'learning_rate': 0.006707875155583579, 'max_depth': 8, 'min_child_weight': 40.105462451336706, 'n_estimators': 1184, 'reg_lambda': 14.548182400614586, 'subsample': 0.5215799559752881}
# Roc-AUC actual; 0.8927726259374957
# Con grid: {'colsample_bytree': 0.9619000897943248, 'gamma': 7.915516636294498, 'learning_rate': 0.02978894388357901, 'max_depth': 7, 'min_child_weight': 12.649508399462055, 'n_estimators': 2182, 'reg_lambda': 14.539538034286485, 'subsample': 0.7615489220850744}
# Roc-AUC actual; 0.8900053851540384
# Con grid: {'colsample_bytree': 0.8702895233473419, 'gamma': 10.436230334769258, 'learning_rate': 0.013636231943033197, 'max_depth': 7, 'min_child_weight': 34.84625279319074, 'n_estimators': 1782, 'reg_lambda': 13.517370157364835, 'subsample': 0.522723190170729}
# Roc-AUC actual; 0.887340047192056
# Con grid: {'colsample_bytree': 0.7483371163572806, 'gamma': 14.25617226114838, 'learning_rate': 0.026707913516727487, 'max_depth': 10, 'min_child_weight': 31.006629890076837, 'n_estimators': 1531, 'reg_lambda': 2.545198558433483, 'subsample': 0.8234241808343619}
# Roc-AUC actual; 0.8947557458924293
# Con grid: {'colsample_bytree': 0.7858939343964553, 'gamma': 3.440921185574245, 'learning_rate': 0.007978137748927168, 'max_depth': 7, 'min_child_weight': 48.71974038330833, 'n_estimators': 2227, 'reg_lambda': 6.798612702432465, 'subsample': 0.5161579755548252}
# Roc-AUC actual; 0.8929115313337803
# Con grid: {'colsample_bytree': 0.747917227509131, 'gamma': 6.168100813082794, 'learning_rate': 0.018083456460698956, 'max_depth': 5, 'min_child_weight': 41.12686214615845, 'n_estimators': 2117, 'reg_lambda': 6.249585866077188, 'subsample': 0.7905813105904131}
# Roc-AUC actual; 0.895634066420721
# Con grid: {'colsample_bytree': 0.9717117931424459, 'gamma': 1.241226300529592, 'learning_rate': 0.02629984457777378, 'max_depth': 7, 'min_child_weight': 1.3183487248626002, 'n_estimators': 2324, 'reg_lambda': 11.664034256028383, 'subsample': 0.7401850409331774}
# Roc-AUC actual; 0.8956312584081286
# Con grid: {'colsample_bytree': 0.9948501177329265, 'gamma': 5.651084549069111, 'learning_rate': 0.02248734899928216, 'max_depth': 11, 'min_child_weight': 48.49571989073016, 'n_estimators': 1294, 'reg_lambda': 8.536222037486215, 'subsample': 0.5317559147950006}
# Roc-AUC actual; 0.8757907359009777
# Con grid: {'colsample_bytree': 0.662887653672597, 'gamma': 2.0077817820094976, 'learning_rate': 0.00041015894480991855, 'max_depth': 9, 'min_child_weight': 43.23611881275266, 'n_estimators': 1208, 'reg_lambda': 14.995765099291958, 'subsample': 0.9983184185369527}
# Roc-AUC actual; 0.8891541657298466
# Con grid: {'colsample_bytree': 0.8444010969609196, 'gamma': 11.534811227707657, 'learning_rate': 0.02834297189647284, 'max_depth': 5, 'min_child_weight': 12.367405087159883, 'n_estimators': 1601, 'reg_lambda': 3.0756799275978737, 'subsample': 0.6257212197558992}
# Roc-AUC actual; 0.8956185622751243
# Con grid: {'colsample_bytree': 0.7461561289590681, 'gamma': 3.1084147351208467, 'learning_rate': 0.026346620024375766, 'max_depth': 10, 'min_child_weight': 30.90641202289479, 'n_estimators': 1871, 'reg_lambda': 4.0300872303796105, 'subsample': 0.5110923710151508}
# Roc-AUC actual; 0.8922589465372737
# Con grid: {'colsample_bytree': 0.8243578153260626, 'gamma': 7.143160451835213, 'learning_rate': 0.024941144701875036, 'max_depth': 4, 'min_child_weight': 42.609075015927004, 'n_estimators': 1577, 'reg_lambda': 14.519606481597346, 'subsample': 0.5442041116828233}
# Roc-AUC actual; 0.8904846608373809
# Con grid: {'colsample_bytree': 0.9271362438143715, 'gamma': 8.84933845706454, 'learning_rate': 0.014401379010554253, 'max_depth': 9, 'min_child_weight': 37.75686278368095, 'n_estimators': 1352, 'reg_lambda': 9.590420354613634, 'subsample': 0.9025223337596809}
# Roc-AUC actual; 0.8907234086592131
# Con grid: {'colsample_bytree': 0.9661028705368192, 'gamma': 9.25895568145938, 'learning_rate': 0.029413881752771334, 'max_depth': 4, 'min_child_weight': 29.495884342731653, 'n_estimators': 1297, 'reg_lambda': 8.322234128133385, 'subsample': 0.5455010455256651}
# Roc-AUC actual; 0.8902304044198528
# Con grid: {'colsample_bytree': 0.9042389614275799, 'gamma': 8.211694603486674, 'learning_rate': 0.013527313422483133, 'max_depth': 9, 'min_child_weight': 26.18011380075056, 'n_estimators': 580, 'reg_lambda': 14.242809354864631, 'subsample': 0.573536740464519}
# Roc-AUC actual; 0.8946751011948106
# Con grid: {'colsample_bytree': 0.974305668806523, 'gamma': 7.381744396193072, 'learning_rate': 0.00774733164896875, 'max_depth': 10, 'min_child_weight': 2.2930633202316475, 'n_estimators': 2297, 'reg_lambda': 7.389271409893044, 'subsample': 0.664375805143754}
# Roc-AUC actual; 0.8885555027852904
# Con grid: {'colsample_bytree': 0.871690299010854, 'gamma': 3.602184281672896, 'learning_rate': 0.0022758998432599177, 'max_depth': 11, 'min_child_weight': 23.0059579491786, 'n_estimators': 1347, 'reg_lambda': 2.278540402684415, 'subsample': 0.5694135863247051}
# Roc-AUC actual; 0.8887020045009015
# Con grid: {'colsample_bytree': 0.8743061606811251, 'gamma': 2.728201265987172, 'learning_rate': 0.010370018499715895, 'max_depth': 5, 'min_child_weight': 43.71588024272086, 'n_estimators': 1166, 'reg_lambda': 10.013366077815407, 'subsample': 0.5861599356008149}
# Roc-AUC actual; 0.8957570137612909
# Con grid: {'colsample_bytree': 0.7173011565830347, 'gamma': 0.613029243997183, 'learning_rate': 0.005068051892164936, 'max_depth': 8, 'min_child_weight': 4.43512668785278, 'n_estimators': 2036, 'reg_lambda': 8.016352555987845, 'subsample': 0.677995742135993}
# Roc-AUC actual; 0.8934713048614681
# Con grid: {'colsample_bytree': 0.962976042013574, 'gamma': 1.9312259744946587, 'learning_rate': 0.009902985399304662, 'max_depth': 11, 'min_child_weight': 4.6145293114373045, 'n_estimators': 546, 'reg_lambda': 9.418505842363617, 'subsample': 0.540879515974436}
# Roc-AUC actual; 0.8743821415525646
# Con grid: {'colsample_bytree': 0.9557525184373721, 'gamma': 13.813086007977198, 'learning_rate': 0.0018323387956459124, 'max_depth': 6, 'min_child_weight': 40.31006398965307, 'n_estimators': 1124, 'reg_lambda': 8.959171233831459, 'subsample': 0.9931284979334076}
# Roc-AUC actual; 0.8856912765399689
# Con grid: {'colsample_bytree': 0.8378067260955664, 'gamma': 13.860626386611496, 'learning_rate': 0.0070834959935221296, 'max_depth': 9, 'min_child_weight': 26.563287698676703, 'n_estimators': 1909, 'reg_lambda': 11.212064072006347, 'subsample': 0.518341601445299}
# Roc-AUC actual; 0.8884456298361564
# Con grid: {'colsample_bytree': 0.7383529305204073, 'gamma': 10.700243788268287, 'learning_rate': 0.026856205130615977, 'max_depth': 4, 'min_child_weight': 22.370618341172733, 'n_estimators': 1238, 'reg_lambda': 5.957457487561237, 'subsample': 0.5524345832662405}
# Roc-AUC actual; 0.8895566905523664
# Con grid: {'colsample_bytree': 0.9080918221328367, 'gamma': 2.734258177139371, 'learning_rate': 0.01691895276056509, 'max_depth': 3, 'min_child_weight': 10.572400349827232, 'n_estimators': 1997, 'reg_lambda': 8.030033460232852, 'subsample': 0.6166082057749006}
# Roc-AUC actual; 0.8915861048892297
# Con grid: {'colsample_bytree': 0.7700244024973911, 'gamma': 7.109549121458342, 'learning_rate': 0.010653129098379142, 'max_depth': 11, 'min_child_weight': 24.922109946452863, 'n_estimators': 610, 'reg_lambda': 8.76299227071254, 'subsample': 0.8684112376974564}
# Roc-AUC actual; 0.8917670192219186
# Con grid: {'colsample_bytree': 0.8452097930826531, 'gamma': 8.798031519911387, 'learning_rate': 0.016933756275679238, 'max_depth': 11, 'min_child_weight': 16.872341693595907, 'n_estimators': 1191, 'reg_lambda': 9.688758619974019, 'subsample': 0.7853891523344559}
# Roc-AUC actual; 0.8819741620832573
# Con grid: {'colsample_bytree': 0.7746338540642462, 'gamma': 14.797728731894695, 'learning_rate': 0.018173244580706613, 'max_depth': 3, 'min_child_weight': 0.376718156703737, 'n_estimators': 776, 'reg_lambda': 2.2928870877649805, 'subsample': 0.622978864192254}
# Roc-AUC actual; 0.8944765066180186
# Con grid: {'colsample_bytree': 0.7062384806408445, 'gamma': 2.7985053607695862, 'learning_rate': 0.008552855060815413, 'max_depth': 10, 'min_child_weight': 44.83827123132126, 'n_estimators': 1258, 'reg_lambda': 0.7745321681176925, 'subsample': 0.5091212407141805}
# Roc-AUC actual; 0.8841503629420803
# Con grid: {'colsample_bytree': 0.8939365118282475, 'gamma': 14.958833021525916, 'learning_rate': 0.026898307889220624, 'max_depth': 6, 'min_child_weight': 48.473521663768445, 'n_estimators': 503, 'reg_lambda': 0.07950009596408125, 'subsample': 0.9875335814725712}
# Roc-AUC actual; 0.8860738960687877
# Con grid: {'colsample_bytree': 0.8217620727405746, 'gamma': 10.843441449326635, 'learning_rate': 0.024625844194600576, 'max_depth': 4, 'min_child_weight': 27.83814465069649, 'n_estimators': 1915, 'reg_lambda': 7.149292261896179, 'subsample': 0.9192912793513124}
# Roc-AUC actual; 0.884951954860045
# Con grid: {'colsample_bytree': 0.7217771460523107, 'gamma': 14.519910997563514, 'learning_rate': 0.021328574365102448, 'max_depth': 6, 'min_child_weight': 25.38051893422275, 'n_estimators': 612, 'reg_lambda': 7.94760034771675, 'subsample': 0.8536150478222222}
# Roc-AUC actual; 0.892382334437664
# Con grid: {'colsample_bytree': 0.9187228255049935, 'gamma': 1.3093526938451316, 'learning_rate': 0.01518311869078041, 'max_depth': 6, 'min_child_weight': 16.032109607975713, 'n_estimators': 758, 'reg_lambda': 0.7773530523364036, 'subsample': 0.6683021390969603}
# Roc-AUC actual; 0.8965212248460145
# Con grid: {'colsample_bytree': 0.697045136928641, 'gamma': 0.9506245570915162, 'learning_rate': 0.029698806971698355, 'max_depth': 10, 'min_child_weight': 40.493722292731746, 'n_estimators': 820, 'reg_lambda': 2.0823716016303058, 'subsample': 0.5013554497071648}
# ----------
# Mejor valor de ROC-AUC encontrado: 0.8965212248460145
# Grid{'colsample_bytree': 0.697045136928641, 'gamma': 0.9506245570915162, 'learning_rate': 0.029698806971698355, 'max_depth': 10, 'min_child_weight': 40.493722292731746, 'n_estimators': 820, 'reg_lambda': 2.0823716016303058, 'subsample': 0.5013554497071648}
# ----------
# Roc-AUC actual; 0.8908060781519657
# Con grid: {'colsample_bytree': 0.6908436224495885, 'gamma': 7.097493015778383, 'learning_rate': 0.018183056431675157, 'max_depth': 5, 'min_child_weight': 17.443413327149766, 'n_estimators': 2340, 'reg_lambda': 12.760911900246821, 'subsample': 0.8729872627743591}
# Roc-AUC actual; 0.8840581435364544
# Con grid: {'colsample_bytree': 0.792981402527571, 'gamma': 13.99407100649932, 'learning_rate': 0.029727884293721717, 'max_depth': 4, 'min_child_weight': 9.061653308283008, 'n_estimators': 2070, 'reg_lambda': 13.896741353845668, 'subsample': 0.8607982753756386}
# Roc-AUC actual; 0.8882281534884781
# Con grid: {'colsample_bytree': 0.6668331253874307, 'gamma': 11.722717226271223, 'learning_rate': 0.024838226615324758, 'max_depth': 7, 'min_child_weight': 10.081366002387227, 'n_estimators': 1297, 'reg_lambda': 12.376990150391958, 'subsample': 0.593202493394072}
# Roc-AUC actual; 0.8899321899224727
# Con grid: {'colsample_bytree': 0.7324921111227499, 'gamma': 9.50637845580266, 'learning_rate': 0.027235983913875477, 'max_depth': 11, 'min_child_weight': 43.86002704065541, 'n_estimators': 588, 'reg_lambda': 10.244730951256987, 'subsample': 0.7259743006495196}
# Roc-AUC actual; 0.8806788450098626
# Con grid: {'colsample_bytree': 0.8998238591993641, 'gamma': 13.495011679382596, 'learning_rate': 0.018723046325455128, 'max_depth': 3, 'min_child_weight': 37.380469008812554, 'n_estimators': 642, 'reg_lambda': 8.662294063591885, 'subsample': 0.677681225909198}
# Roc-AUC actual; 0.8888255348044661
# Con grid: {'colsample_bytree': 0.7870187385705256, 'gamma': 7.97786219532261, 'learning_rate': 0.001998573371724509, 'max_depth': 10, 'min_child_weight': 31.211899795699605, 'n_estimators': 2470, 'reg_lambda': 6.472922147046639, 'subsample': 0.6664078929562421}
# Roc-AUC actual; 0.8769175232677442
# Con grid: {'colsample_bytree': 0.9056921978832555, 'gamma': 10.405764111050077, 'learning_rate': 0.005001922799801495, 'max_depth': 3, 'min_child_weight': 26.673054598816076, 'n_estimators': 1754, 'reg_lambda': 8.597262738860831, 'subsample': 0.9988463079619216}
# Roc-AUC actual; 0.885524945182343
# Con grid: {'colsample_bytree': 0.9133410920135879, 'gamma': 10.604706918651885, 'learning_rate': 0.02335715817152253, 'max_depth': 3, 'min_child_weight': 1.676621736788969, 'n_estimators': 1097, 'reg_lambda': 10.710961233354212, 'subsample': 0.7469907435654313}
# Roc-AUC actual; 0.895754325901377
# Con grid: {'colsample_bytree': 0.9141223521510409, 'gamma': 1.5437404611621752, 'learning_rate': 0.016094440544537843, 'max_depth': 6, 'min_child_weight': 22.850010964083918, 'n_estimators': 1447, 'reg_lambda': 5.959309358405509, 'subsample': 0.8986476828897768}
# Roc-AUC actual; 0.8914187188580945
# Con grid: {'colsample_bytree': 0.7024710995720709, 'gamma': 3.4387709284896224, 'learning_rate': 0.021667577051791988, 'max_depth': 4, 'min_child_weight': 0.6101536159022258, 'n_estimators': 1126, 'reg_lambda': 10.4092266670065, 'subsample': 0.7713622216737981}
# Roc-AUC actual; 0.892292184328164
# Con grid: {'colsample_bytree': 0.7381296706174335, 'gamma': 5.185439902558792, 'learning_rate': 0.00544793150404277, 'max_depth': 10, 'min_child_weight': 29.169589738306023, 'n_estimators': 1211, 'reg_lambda': 6.353952936307243, 'subsample': 0.6439648082378631}
# Roc-AUC actual; 0.881749351972105
# Con grid: {'colsample_bytree': 0.8652325921034291, 'gamma': 13.67778613264447, 'learning_rate': 0.0041734858242918555, 'max_depth': 4, 'min_child_weight': 30.57271177173239, 'n_estimators': 2146, 'reg_lambda': 10.891433790936011, 'subsample': 0.7964814526294108}
# Roc-AUC actual; 0.8861982451906043
# Con grid: {'colsample_bytree': 0.6857744324788199, 'gamma': 13.781257833911198, 'learning_rate': 0.023702539113722602, 'max_depth': 7, 'min_child_weight': 35.36193171566993, 'n_estimators': 1629, 'reg_lambda': 11.56870002779607, 'subsample': 0.687217684860211}
# Roc-AUC actual; 0.8920095407278685
# Con grid: {'colsample_bytree': 0.6741225387785266, 'gamma': 1.1598159823318088, 'learning_rate': 0.003127408981554285, 'max_depth': 11, 'min_child_weight': 46.278425645338814, 'n_estimators': 1930, 'reg_lambda': 1.842161727686007, 'subsample': 0.6179530172975406}
# Roc-AUC actual; 0.8876251383469089
# Con grid: {'colsample_bytree': 0.7079321786285514, 'gamma': 2.7948131924118105, 'learning_rate': 0.02512472367007476, 'max_depth': 3, 'min_child_weight': 43.49481810310641, 'n_estimators': 1066, 'reg_lambda': 3.410934313156689, 'subsample': 0.8039471968971293}
# Roc-AUC actual; 0.8903400281634317
# Con grid: {'colsample_bytree': 0.7827569944349421, 'gamma': 11.163744777649333, 'learning_rate': 0.006167394251269125, 'max_depth': 11, 'min_child_weight': 0.23160115023014294, 'n_estimators': 1436, 'reg_lambda': 1.7140095008353162, 'subsample': 0.7072522921018138}
# Roc-AUC actual; 0.884535737082301
# Con grid: {'colsample_bytree': 0.9522313492145349, 'gamma': 13.844403476977273, 'learning_rate': 0.013971003669564394, 'max_depth': 4, 'min_child_weight': 45.92273624696506, 'n_estimators': 1139, 'reg_lambda': 3.369072344099729, 'subsample': 0.7262197580663468}
# Roc-AUC actual; 0.8972829616755854
# Con grid: {'colsample_bytree': 0.6992999571329299, 'gamma': 2.6458047975933496, 'learning_rate': 0.014951033182184392, 'max_depth': 8, 'min_child_weight': 1.6939580123297493, 'n_estimators': 1684, 'reg_lambda': 5.435908486749497, 'subsample': 0.7902941751390218}
# ----------
# Mejor valor de ROC-AUC encontrado: 0.8972829616755854
# Grid{'colsample_bytree': 0.6992999571329299, 'gamma': 2.6458047975933496, 'learning_rate': 0.014951033182184392, 'max_depth': 8, 'min_child_weight': 1.6939580123297493, 'n_estimators': 1684, 'reg_lambda': 5.435908486749497, 'subsample': 0.7902941751390218}
# ----------
# Roc-AUC actual; 0.8968430693701221
# Con grid: {'colsample_bytree': 0.8712925007718356, 'gamma': 0.19641684882500454, 'learning_rate': 0.019906121160501316, 'max_depth': 9, 'min_child_weight': 48.77706578413781, 'n_estimators': 1884, 'reg_lambda': 2.2299409162966946, 'subsample': 0.7073120618635118}
# Roc-AUC actual; 0.8826672961836324
# Con grid: {'colsample_bytree': 0.6798723838275254, 'gamma': 14.953113777689211, 'learning_rate': 0.015065850309937278, 'max_depth': 3, 'min_child_weight': 15.496846313430545, 'n_estimators': 1489, 'reg_lambda': 11.249407055987668, 'subsample': 0.6049527965477929}
# Roc-AUC actual; 0.8931617693117351
# Con grid: {'colsample_bytree': 0.9643190013042497, 'gamma': 3.0770946072301077, 'learning_rate': 0.005720631619909997, 'max_depth': 10, 'min_child_weight': 29.372680211703717, 'n_estimators': 1268, 'reg_lambda': 11.63291425042516, 'subsample': 0.7266444173740139}
# Roc-AUC actual; 0.8920349062932823
# Con grid: {'colsample_bytree': 0.833536594264653, 'gamma': 6.611441204073422, 'learning_rate': 0.012022891826259778, 'max_depth': 8, 'min_child_weight': 38.26781405331203, 'n_estimators': 2167, 'reg_lambda': 2.728921957429067, 'subsample': 0.9308928105067587}
# Roc-AUC actual; 0.8755860624886844
# Con grid: {'colsample_bytree': 0.9811404117467715, 'gamma': 5.599639744196294, 'learning_rate': 0.008122340194306613, 'max_depth': 4, 'min_child_weight': 20.43670855490482, 'n_estimators': 586, 'reg_lambda': 14.683971534239419, 'subsample': 0.9198944297282853}
# Roc-AUC actual; 0.8910271679801907
# Con grid: {'colsample_bytree': 0.9534478160040332, 'gamma': 6.11976743047267, 'learning_rate': 0.01655167785778019, 'max_depth': 5, 'min_child_weight': 11.55373982940357, 'n_estimators': 942, 'reg_lambda': 7.582618186590507, 'subsample': 0.7975244898502103}
# Roc-AUC actual; 0.8911672571028613
# Con grid: {'colsample_bytree': 0.7687449360636669, 'gamma': 8.541652766452504, 'learning_rate': 0.02662381447540509, 'max_depth': 10, 'min_child_weight': 4.972069637967258, 'n_estimators': 595, 'reg_lambda': 14.830931729331642, 'subsample': 0.8015987010884897}
# Roc-AUC actual; 0.8868811351626315
# Con grid: {'colsample_bytree': 0.9323975521369051, 'gamma': 14.439739778323121, 'learning_rate': 0.0283322917673182, 'max_depth': 8, 'min_child_weight': 10.249214770791049, 'n_estimators': 1234, 'reg_lambda': 4.859850916601994, 'subsample': 0.5434625074751747}
# Roc-AUC actual; 0.8855696642291575
# Con grid: {'colsample_bytree': 0.8716342712188362, 'gamma': 11.038569197940035, 'learning_rate': 0.025443842864006503, 'max_depth': 5, 'min_child_weight': 29.152078048484608, 'n_estimators': 1199, 'reg_lambda': 10.559192027077643, 'subsample': 0.955312001770152}
# Roc-AUC actual; 0.892964910273629
# Con grid: {'colsample_bytree': 0.8686664448651379, 'gamma': 5.0379878572475265, 'learning_rate': 0.024753219942679792, 'max_depth': 5, 'min_child_weight': 29.51474712574039, 'n_estimators': 895, 'reg_lambda': 12.459817598478747, 'subsample': 0.6725960724406378}
# Roc-AUC actual; 0.8943114212881673
# Con grid: {'colsample_bytree': 0.9208420831204691, 'gamma': 5.441368419989182, 'learning_rate': 0.025832040599241646, 'max_depth': 5, 'min_child_weight': 47.422665348107834, 'n_estimators': 1353, 'reg_lambda': 11.696381621820462, 'subsample': 0.5571189629601985}
# Roc-AUC actual; 0.8827933630437383
# Con grid: {'colsample_bytree': 0.8480218169882962, 'gamma': 14.78050968362602, 'learning_rate': 0.01413196358081443, 'max_depth': 3, 'min_child_weight': 24.23891835751731, 'n_estimators': 1732, 'reg_lambda': 4.030160390774191, 'subsample': 0.7708171073304335}
# Roc-AUC actual; 0.8776821526617922
# Con grid: {'colsample_bytree': 0.8717173769391515, 'gamma': 3.868315281498034, 'learning_rate': 0.0041806822221847235, 'max_depth': 6, 'min_child_weight': 6.61381055626652, 'n_estimators': 528, 'reg_lambda': 2.5751892877245526, 'subsample': 0.6361536632596845}
# Roc-AUC actual; 0.8750468128184858
# Con grid: {'colsample_bytree': 0.6564367367916134, 'gamma': 13.714482098407485, 'learning_rate': 0.003532532486704234, 'max_depth': 6, 'min_child_weight': 24.904537675550287, 'n_estimators': 533, 'reg_lambda': 8.3126700377369, 'subsample': 0.8257101941759322}
# Roc-AUC actual; 0.8731336929238954
# Con grid: {'colsample_bytree': 0.9404096312975205, 'gamma': 3.0963190764090482, 'learning_rate': 0.00032987485975441433, 'max_depth': 7, 'min_child_weight': 13.184190131730823, 'n_estimators': 1810, 'reg_lambda': 13.108351163437728, 'subsample': 0.7987065510851541}
# Roc-AUC actual; 0.8794727969263272
# Con grid: {'colsample_bytree': 0.8601809011517787, 'gamma': 9.975550118193832, 'learning_rate': 0.005261138358703487, 'max_depth': 3, 'min_child_weight': 20.938526244603654, 'n_estimators': 1999, 'reg_lambda': 11.563670655964057, 'subsample': 0.7110180297753437}
# Roc-AUC actual; 0.8859278171126
# Con grid: {'colsample_bytree': 0.7738549817964373, 'gamma': 14.379407659698309, 'learning_rate': 0.005531127620368896, 'max_depth': 7, 'min_child_weight': 30.15760547331941, 'n_estimators': 1293, 'reg_lambda': 1.0237455803113737, 'subsample': 0.9185394953515147}
# Roc-AUC actual; 0.8869470678323103
# Con grid: {'colsample_bytree': 0.8030176887250352, 'gamma': 13.73270515937871, 'learning_rate': 0.021645985833657167, 'max_depth': 10, 'min_child_weight': 28.32023201484486, 'n_estimators': 597, 'reg_lambda': 5.949740595780814, 'subsample': 0.9770434682698166}
# Roc-AUC actual; 0.8928040569881127
# Con grid: {'colsample_bytree': 0.6972504470974225, 'gamma': 7.256324128986192, 'learning_rate': 0.008097336671765846, 'max_depth': 6, 'min_child_weight': 8.10069389457923, 'n_estimators': 1767, 'reg_lambda': 0.7713872022637552, 'subsample': 0.7481831236006182}
# Roc-AUC actual; 0.8952107685351571
# Con grid: {'colsample_bytree': 0.8588949971209112, 'gamma': 5.013658362254413, 'learning_rate': 0.023127366112374658, 'max_depth': 7, 'min_child_weight': 17.21918660221166, 'n_estimators': 795, 'reg_lambda': 10.92283134305405, 'subsample': 0.7477456581030992}
# Roc-AUC actual; 0.8793586563320648
# Con grid: {'colsample_bytree': 0.8909408387497076, 'gamma': 6.522410079056193, 'learning_rate': 0.007392060997173204, 'max_depth': 5, 'min_child_weight': 3.888267203947854, 'n_estimators': 607, 'reg_lambda': 10.420447062816402, 'subsample': 0.6360725686149813}
# Roc-AUC actual; 0.8671213419049839
# Con grid: {'colsample_bytree': 0.8565807334041805, 'gamma': 5.414608454100402, 'learning_rate': 0.0027474621997990245, 'max_depth': 3, 'min_child_weight': 6.84093154594807, 'n_estimators': 829, 'reg_lambda': 10.358403486684608, 'subsample': 0.7606503337067847}
# Roc-AUC actual; 0.88575177563853
# Con grid: {'colsample_bytree': 0.6803468241517643, 'gamma': 14.372561895058956, 'learning_rate': 0.022751772418370442, 'max_depth': 7, 'min_child_weight': 37.95179227694249, 'n_estimators': 2008, 'reg_lambda': 10.384148467767787, 'subsample': 0.9245978257826597}
# Roc-AUC actual; 0.8876947334482254
# Con grid: {'colsample_bytree': 0.737383803100715, 'gamma': 7.341374454647108, 'learning_rate': 0.0066362832545880665, 'max_depth': 11, 'min_child_weight': 47.202966984330665, 'n_estimators': 546, 'reg_lambda': 0.6624815656515026, 'subsample': 0.7941318784849656}
# Roc-AUC actual; 0.8932474337212459
# Con grid: {'colsample_bytree': 0.9997737248480423, 'gamma': 8.337098721557695, 'learning_rate': 0.014196303542440001, 'max_depth': 9, 'min_child_weight': 1.697298929289942, 'n_estimators': 1128, 'reg_lambda': 10.965355071874225, 'subsample': 0.5962995138928152}
# Roc-AUC actual; 0.8922700050337742
# Con grid: {'colsample_bytree': 0.6903487074365495, 'gamma': 6.326439895957688, 'learning_rate': 0.02386025513877292, 'max_depth': 6, 'min_child_weight': 42.22746992675352, 'n_estimators': 901, 'reg_lambda': 7.836518641067534, 'subsample': 0.8222733253129111}
# Roc-AUC actual; 0.8912690709223522
# Con grid: {'colsample_bytree': 0.8775585726551298, 'gamma': 5.470458741859588, 'learning_rate': 0.01682031582010542, 'max_depth': 4, 'min_child_weight': 44.24991782616405, 'n_estimators': 1694, 'reg_lambda': 5.098124456520992, 'subsample': 0.8623833857643808}
# Roc-AUC actual; 0.8962374553706227
# Con grid: {'colsample_bytree': 0.6728747192796298, 'gamma': 4.729355067459155, 'learning_rate': 0.016184738771260115, 'max_depth': 8, 'min_child_weight': 15.937625146603496, 'n_estimators': 1221, 'reg_lambda': 7.802521648180978, 'subsample': 0.7134085283274322}
# Roc-AUC actual; 0.8893568499477994
# Con grid: {'colsample_bytree': 0.9568328822518573, 'gamma': 6.262591260418382, 'learning_rate': 0.013858285517267628, 'max_depth': 4, 'min_child_weight': 1.063470542519357, 'n_estimators': 1258, 'reg_lambda': 2.7820936436508372, 'subsample': 0.6919819449598629}
# Roc-AUC actual; 0.861347453901556
# Con grid: {'colsample_bytree': 0.9764064682988385, 'gamma': 1.0504455862120654, 'learning_rate': 0.0002845630088549422, 'max_depth': 3, 'min_child_weight': 20.096545680462107, 'n_estimators': 744, 'reg_lambda': 7.196719902847572, 'subsample': 0.7903786036136639}
# Roc-AUC actual; 0.8853254383352157
# Con grid: {'colsample_bytree': 0.7450904398741515, 'gamma': 5.974310759634534, 'learning_rate': 0.002750980053342904, 'max_depth': 9, 'min_child_weight': 26.125959581726153, 'n_estimators': 1076, 'reg_lambda': 3.5816571865245352, 'subsample': 0.5552370565656973}
# Roc-AUC actual; 0.8931944330398291
# Con grid: {'colsample_bytree': 0.7741177551742718, 'gamma': 4.308584874811226, 'learning_rate': 0.008889243613679702, 'max_depth': 7, 'min_child_weight': 2.104659481818094, 'n_estimators': 1204, 'reg_lambda': 13.655086530863015, 'subsample': 0.5225503386101615}
# Roc-AUC actual; 0.8867148171553033
# Con grid: {'colsample_bytree': 0.6883136595376903, 'gamma': 5.8744521081053405, 'learning_rate': 0.0037331267189056904, 'max_depth': 7, 'min_child_weight': 39.3172507207776, 'n_estimators': 1438, 'reg_lambda': 8.82831343459868, 'subsample': 0.9911652575400408}
# Roc-AUC actual; 0.890283818960495
# Con grid: {'colsample_bytree': 0.959469642346026, 'gamma': 9.01197669663297, 'learning_rate': 0.027111719015258114, 'max_depth': 4, 'min_child_weight': 8.35169730460376, 'n_estimators': 1063, 'reg_lambda': 0.9747961422434104, 'subsample': 0.7007901182127437}
# Roc-AUC actual; 0.8933690193314623
# Con grid: {'colsample_bytree': 0.9432390073491359, 'gamma': 3.458537937075285, 'learning_rate': 0.024919275532518735, 'max_depth': 4, 'min_child_weight': 19.20453057456248, 'n_estimators': 1436, 'reg_lambda': 2.7965739321638177, 'subsample': 0.8897922367833766}
# Roc-AUC actual; 0.8911242424440387
# Con grid: {'colsample_bytree': 0.7725438407083556, 'gamma': 0.8676401484509455, 'learning_rate': 0.02907307890422434, 'max_depth': 3, 'min_child_weight': 25.91301833381961, 'n_estimators': 1543, 'reg_lambda': 14.923617339696529, 'subsample': 0.5869476246097436}
# Roc-AUC actual; 0.89012367769085
# Con grid: {'colsample_bytree': 0.7886847066159306, 'gamma': 11.37357713556137, 'learning_rate': 0.020880618541613764, 'max_depth': 10, 'min_child_weight': 44.871807402310196, 'n_estimators': 2262, 'reg_lambda': 3.36660857754991, 'subsample': 0.6119088074113115}
# Roc-AUC actual; 0.889868584654673
# Con grid: {'colsample_bytree': 0.8379410480126948, 'gamma': 8.894099022625547, 'learning_rate': 0.017402586235134333, 'max_depth': 4, 'min_child_weight': 22.871604888685365, 'n_estimators': 1451, 'reg_lambda': 3.984000638830591, 'subsample': 0.5647574606414021}
# Roc-AUC actual; 0.8869269756344431
# Con grid: {'colsample_bytree': 0.9610618279541421, 'gamma': 14.3347724734463, 'learning_rate': 0.025863828517963518, 'max_depth': 11, 'min_child_weight': 16.45256826849355, 'n_estimators': 2060, 'reg_lambda': 8.26286055913709, 'subsample': 0.5434933799557051}
# Roc-AUC actual; 0.8944109744572672
# Con grid: {'colsample_bytree': 0.7929586245747445, 'gamma': 5.59032775518471, 'learning_rate': 0.007792613512809786, 'max_depth': 7, 'min_child_weight': 2.4391790836586544, 'n_estimators': 1413, 'reg_lambda': 1.215693238614719, 'subsample': 0.6100916009749057}
# Roc-AUC actual; 0.8964839196644596
# Con grid: {'colsample_bytree': 0.8891405672808586, 'gamma': 1.1419628923545027, 'learning_rate': 0.02553620742146306, 'max_depth': 10, 'min_child_weight': 44.14531345687306, 'n_estimators': 817, 'reg_lambda': 8.886116769892764, 'subsample': 0.9123404829625745}
# ...
# Con grid: {'colsample_bytree': 0.7942458255919701, 'gamma': 8.244240655783868, 'learning_rate': 0.024916033692145196, 'max_depth': 10, 'min_child_weight': 13.2523214162502, 'n_estimators': 2073, 'reg_lambda': 1.2392649518890302, 'subsample': 0.7573287932867558}
# Roc-AUC actual; 0.889875415556938
# Con grid: {'colsample_bytree': 0.9646152884021824, 'gamma': 11.737273868459068, 'learning_rate': 0.006835272526293299, 'max_depth': 11, 'min_child_weight': 19.096981982644795, 'n_estimators': 1445, 'reg_lambda': 0.156415490961046, 'subsample': 0.6277067423426097}
# Roc-AUC actual; 0.8955386518438728
# Con grid: {'colsample_bytree': 0.7412496549719708, 'gamma': 1.038814594287899, 'learning_rate': 0.02879479554227787, 'max_depth': 9, 'min_child_weight': 2.0975611715818134, 'n_estimators': 869, 'reg_lambda': 4.8332325516694254, 'subsample': 0.5626167852164136}
# Roc-AUC actual; 0.8898031058951124
# Con grid: {'colsample_bytree': 0.8160176384671749, 'gamma': 1.7093495207147575, 'learning_rate': 0.014580465089326197, 'max_depth': 4, 'min_child_weight': 6.404787318310001, 'n_estimators': 1282, 'reg_lambda': 1.6621194326971056, 'subsample': 0.7992657878421828}
# Roc-AUC actual; 0.8945116891022571
# Con grid: {'colsample_bytree': 0.6832540946473067, 'gamma': 5.639893349119671, 'learning_rate': 0.01650275821374468, 'max_depth': 11, 'min_child_weight': 8.184190073265075, 'n_estimators': 913, 'reg_lambda': 13.924762992728654, 'subsample': 0.8379911377931777}
# Roc-AUC actual; 0.896505337991887
# Con grid: {'colsample_bytree': 0.8236167435379603, 'gamma': 0.19072334980340278, 'learning_rate': 0.029772462014684104, 'max_depth': 9, 'min_child_weight': 43.96343299989191, 'n_estimators': 1279, 'reg_lambda': 13.783898004593317, 'subsample': 0.6261205100866808}
# Roc-AUC actual; 0.8946283395524657
# Con grid: {'colsample_bytree': 0.9142646750611974, 'gamma': 6.9080924591121, 'learning_rate': 0.025259956586701843, 'max_depth': 10, 'min_child_weight': 27.890661275553498, 'n_estimators': 1162, 'reg_lambda': 9.842427565216072, 'subsample': 0.5887143847348535}
# Roc-AUC actual; 0.8827886014375992
# Con grid: {'colsample_bytree': 0.8407594216139285, 'gamma': 14.770046092867624, 'learning_rate': 0.028121641994913568, 'max_depth': 4, 'min_child_weight': 5.3971857323232175, 'n_estimators': 712, 'reg_lambda': 10.889698649779433, 'subsample': 0.9088926649284725}
# Roc-AUC actual; 0.8926301337612595
# Con grid: {'colsample_bytree': 0.7247289782087352, 'gamma': 7.587790394277435, 'learning_rate': 0.025221090840336, 'max_depth': 8, 'min_child_weight': 27.111860274592413, 'n_estimators': 2224, 'reg_lambda': 11.151356791149139, 'subsample': 0.8059702526686655}
# Roc-AUC actual; 0.8910277598433836
# Con grid: {'colsample_bytree': 0.6870757493954726, 'gamma': 2.2735405738151035, 'learning_rate': 0.0028127076193666988, 'max_depth': 11, 'min_child_weight': 38.0560768521579, 'n_estimators': 1634, 'reg_lambda': 2.412722609366193, 'subsample': 0.7790211625744835}
# Roc-AUC actual; 0.8885760043922835
# Con grid: {'colsample_bytree': 0.9341132759029984, 'gamma': 11.12568092269395, 'learning_rate': 0.02644352339025064, 'max_depth': 6, 'min_child_weight': 4.9589049793607956, 'n_estimators': 1747, 'reg_lambda': 13.19724728912908, 'subsample': 0.8287801563890116}
# Roc-AUC actual; 0.8872110299161834
# Con grid: {'colsample_bytree': 0.7588251255026439, 'gamma': 11.135220758587637, 'learning_rate': 0.024453551534411037, 'max_depth': 4, 'min_child_weight': 17.769228434286973, 'n_estimators': 1536, 'reg_lambda': 8.080435010145587, 'subsample': 0.7620795853630811}
# Roc-AUC actual; 0.8877009680371981
# Con grid: {'colsample_bytree': 0.9468167268957701, 'gamma': 12.59945970423274, 'learning_rate': 0.024980414080411295, 'max_depth': 11, 'min_child_weight': 47.90367400596901, 'n_estimators': 1900, 'reg_lambda': 10.175682342827127, 'subsample': 0.8781323289457263}
# Roc-AUC actual; 0.8909336936465916
# Con grid: {'colsample_bytree': 0.9446896300238481, 'gamma': 7.054785811526784, 'learning_rate': 0.015061506404653414, 'max_depth': 6, 'min_child_weight': 19.26879415236809, 'n_estimators': 1655, 'reg_lambda': 10.831064073041055, 'subsample': 0.9430978902325373}
# Roc-AUC actual; 0.8942412877248481
# Con grid: {'colsample_bytree': 0.8575655169653744, 'gamma': 5.87288547266744, 'learning_rate': 0.012378655225458711, 'max_depth': 10, 'min_child_weight': 8.918629215366492, 'n_estimators': 701, 'reg_lambda': 9.29384006189761, 'subsample': 0.6777465052206787}
# Roc-AUC actual; 0.8963085635056658
# Con grid: {'colsample_bytree': 0.9279690659469795, 'gamma': 1.3948595973469824, 'learning_rate': 0.017646068008451716, 'max_depth': 6, 'min_child_weight': 25.505485624941258, 'n_estimators': 2038, 'reg_lambda': 0.9728039172445252, 'subsample': 0.7899918937140656}
# Roc-AUC actual; 0.8885125059268646
# Con grid: {'colsample_bytree': 0.8465196057858333, 'gamma': 8.409901416242564, 'learning_rate': 0.018104629997893643, 'max_depth': 4, 'min_child_weight': 29.968448283146692, 'n_estimators': 2438, 'reg_lambda': 4.047310801923215, 'subsample': 0.912524705090031}
# Roc-AUC actual; 0.8836699524834428
# Con grid: {'colsample_bytree': 0.8243894887922087, 'gamma': 1.1558741870149674, 'learning_rate': 0.001756527877319376, 'max_depth': 8, 'min_child_weight': 10.492099742820471, 'n_estimators': 1367, 'reg_lambda': 7.7590358466241405, 'subsample': 0.7200994989777453}
# Roc-AUC actual; 0.8902006021055413
# Con grid: {'colsample_bytree': 0.7016083843471994, 'gamma': 4.922891304139673, 'learning_rate': 0.013020580985216258, 'max_depth': 4, 'min_child_weight': 18.571100093652287, 'n_estimators': 1636, 'reg_lambda': 8.973379410956083, 'subsample': 0.8678315571195949}
# Roc-AUC actual; 0.8834252815795817
# Con grid: {'colsample_bytree': 0.9994216289875324, 'gamma': 13.996699970153365, 'learning_rate': 0.019276955986055746, 'max_depth': 3, 'min_child_weight': 31.877663223511487, 'n_estimators': 1159, 'reg_lambda': 11.78477427120348, 'subsample': 0.5591680954616937}
# Roc-AUC actual; 0.887763438529703
# Con grid: {'colsample_bytree': 0.7934667113937008, 'gamma': 12.597034284534258, 'learning_rate': 0.01151498855799132, 'max_depth': 11, 'min_child_weight': 47.51563764652958, 'n_estimators': 1336, 'reg_lambda': 2.7671437970045902, 'subsample': 0.6811177208261442}
# Roc-AUC actual; 0.8806365468170105
# Con grid: {'colsample_bytree': 0.7670789510596763, 'gamma': 0.3929506279809719, 'learning_rate': 0.0007257529167406573, 'max_depth': 8, 'min_child_weight': 13.65354049864062, 'n_estimators': 2372, 'reg_lambda': 13.944253843135263, 'subsample': 0.891290969925669}
# Roc-AUC actual; 0.886910714971983
# Con grid: {'colsample_bytree': 0.6696476361956736, 'gamma': 12.790920298135669, 'learning_rate': 0.006766239897771979, 'max_depth': 7, 'min_child_weight': 42.09667833959043, 'n_estimators': 2456, 'reg_lambda': 7.213590011296045, 'subsample': 0.7175901996276783}
# Roc-AUC actual; 0.8892684754278785
# Con grid: {'colsample_bytree': 0.9780736529755525, 'gamma': 10.590285114960368, 'learning_rate': 0.01893511937870119, 'max_depth': 9, 'min_child_weight': 45.195666513018736, 'n_estimators': 1430, 'reg_lambda': 6.552760539227693, 'subsample': 0.8647541143261983}
# Roc-AUC actual; 0.8956933194915073
# Con grid: {'colsample_bytree': 0.9179295146468884, 'gamma': 2.3836225150403036, 'learning_rate': 0.018306754484329238, 'max_depth': 11, 'min_child_weight': 37.56875430145229, 'n_estimators': 2187, 'reg_lambda': 7.080906512954974, 'subsample': 0.5067013132160828}
# Roc-AUC actual; 0.8833908645124045
# Con grid: {'colsample_bytree': 0.7489609913525668, 'gamma': 0.6689236255944231, 'learning_rate': 0.0010886286784050647, 'max_depth': 9, 'min_child_weight': 12.348939953599992, 'n_estimators': 1743, 'reg_lambda': 11.80689903902406, 'subsample': 0.9874173263905559}
# Roc-AUC actual; 0.8956570111321723
# Con grid: {'colsample_bytree': 0.7799224828614995, 'gamma': 6.433303182915579, 'learning_rate': 0.02534368308858064, 'max_depth': 8, 'min_child_weight': 3.268307878219262, 'n_estimators': 2336, 'reg_lambda': 12.796344351054756, 'subsample': 0.5232502932200327}
# Roc-AUC actual; 0.8900777882679473
# Con grid: {'colsample_bytree': 0.8668948040697955, 'gamma': 8.429892712002102, 'learning_rate': 0.010377613425050827, 'max_depth': 4, 'min_child_weight': 20.554780130035326, 'n_estimators': 2042, 'reg_lambda': 1.2963691614381974, 'subsample': 0.6183921546556927}
# Roc-AUC actual; 0.8919210816560628
# Con grid: {'colsample_bytree': 0.9063570561433314, 'gamma': 8.224808755896364, 'learning_rate': 0.0038396462560075914, 'max_depth': 9, 'min_child_weight': 19.672392328179576, 'n_estimators': 2189, 'reg_lambda': 6.281899786112421, 'subsample': 0.6300788954810256}
# Roc-AUC actual; 0.8848872459676449
# Con grid: {'colsample_bytree': 0.9057873377432555, 'gamma': 14.7194563574587, 'learning_rate': 0.007695901873327434, 'max_depth': 5, 'min_child_weight': 36.25778637755574, 'n_estimators': 2456, 'reg_lambda': 8.479953818574149, 'subsample': 0.731966243344168}
# Roc-AUC actual; 0.8929200488236404
# Con grid: {'colsample_bytree': 0.990201865371038, 'gamma': 9.127909090446998, 'learning_rate': 0.010485191162604563, 'max_depth': 11, 'min_child_weight': 1.1017580148752093, 'n_estimators': 1128, 'reg_lambda': 3.3797539492685265, 'subsample': 0.625483330670149}
# Roc-AUC actual; 0.8815333308068637
# Con grid: {'colsample_bytree': 0.9477156202443983, 'gamma': 8.418341824237874, 'learning_rate': 0.015701727341230994, 'max_depth': 4, 'min_child_weight': 20.198893816327413, 'n_estimators': 542, 'reg_lambda': 1.0150254285000238, 'subsample': 0.8539175486148843}
# Roc-AUC actual; 0.8875154211512466
# Con grid: {'colsample_bytree': 0.8402383760699261, 'gamma': 1.2258801862016737, 'learning_rate': 0.013749019245859693, 'max_depth': 3, 'min_child_weight': 21.431527348523787, 'n_estimators': 2040, 'reg_lambda': 14.185472205004235, 'subsample': 0.924987685740331}
# Roc-AUC actual; 0.89266259723489
# Con grid: {'colsample_bytree': 0.8841578180651879, 'gamma': 6.934433415009108, 'learning_rate': 0.012352966247535254, 'max_depth': 9, 'min_child_weight': 27.271593470345273, 'n_estimators': 843, 'reg_lambda': 11.804552023764995, 'subsample': 0.5559679635107652}
# Roc-AUC actual; 0.882527852325345
# Con grid: {'colsample_bytree': 0.7745906808281985, 'gamma': 14.670927269602927, 'learning_rate': 0.02381969149104018, 'max_depth': 3, 'min_child_weight': 10.06818910679872, 'n_estimators': 890, 'reg_lambda': 13.082035500337149, 'subsample': 0.7724238795422578}
# Roc-AUC actual; 0.8773398554817825
# Con grid: {'colsample_bytree': 0.9154487562541889, 'gamma': 11.311615204742461, 'learning_rate': 0.0005383703570547548, 'max_depth': 10, 'min_child_weight': 43.89150390760204, 'n_estimators': 2249, 'reg_lambda': 2.4242971692880717, 'subsample': 0.6277466723278023}
# Roc-AUC actual; 0.8909574616263941
# Con grid: {'colsample_bytree': 0.9813232839698625, 'gamma': 8.402733875623678, 'learning_rate': 0.022521885209980413, 'max_depth': 3, 'min_child_weight': 1.358371061277991, 'n_estimators': 2444, 'reg_lambda': 1.4122786518854684, 'subsample': 0.6718315963045516}
# Roc-AUC actual; 0.8959004093076638
# Con grid: {'colsample_bytree': 0.7488508145402791, 'gamma': 5.8609254842041985, 'learning_rate': 0.023950325646729848, 'max_depth': 9, 'min_child_weight': 32.8390052362147, 'n_estimators': 1100, 'reg_lambda': 5.960720857279748, 'subsample': 0.5467039859876478}
# Roc-AUC actual; 0.8919607053392984
# Con grid: {'colsample_bytree': 0.8043752553877743, 'gamma': 2.9341390956677253, 'learning_rate': 0.005601698873191244, 'max_depth': 10, 'min_child_weight': 14.356897904228777, 'n_estimators': 975, 'reg_lambda': 11.36222827184126, 'subsample': 0.638220845291698}
# Roc-AUC actual; 0.8897203251498799
# Con grid: {'colsample_bytree': 0.7593221856599297, 'gamma': 9.640119865086355, 'learning_rate': 0.005875224377607566, 'max_depth': 10, 'min_child_weight': 26.00952616257772, 'n_estimators': 1327, 'reg_lambda': 10.438486772532038, 'subsample': 0.8966306752191272}
# Roc-AUC actual; 0.8865188036360443
# Con grid: {'colsample_bytree': 0.7608665869736344, 'gamma': 12.857688854981294, 'learning_rate': 0.02718429764297299, 'max_depth': 4, 'min_child_weight': 8.442710333884307, 'n_estimators': 985, 'reg_lambda': 2.110672920731376, 'subsample': 0.601007834201245}
# Roc-AUC actual; 0.8860866100021889
# Con grid: {'colsample_bytree': 0.7144786937333092, 'gamma': 13.409845650118056, 'learning_rate': 0.019628776569748856, 'max_depth': 7, 'min_child_weight': 22.016170918417448, 'n_estimators': 1465, 'reg_lambda': 14.516338156550832, 'subsample': 0.928436968037547}
# Roc-AUC actual; 0.8844927446739744
# Con grid: {'colsample_bytree': 0.6911753958557638, 'gamma': 11.095954981283109, 'learning_rate': 0.009590004973216342, 'max_depth': 3, 'min_child_weight': 20.888048963754986, 'n_estimators': 2410, 'reg_lambda': 1.8365084753841154, 'subsample': 0.8625927740136954}
# Roc-AUC actual; 0.886084562956559
# Con grid: {'colsample_bytree': 0.7630539194351749, 'gamma': 14.956172356224926, 'learning_rate': 0.029393473735635656, 'max_depth': 9, 'min_child_weight': 6.491322447585879, 'n_estimators': 2360, 'reg_lambda': 8.396335254575739, 'subsample': 0.7636998110613382}
# Roc-AUC actual; 0.8833571772614955
# Con grid: {'colsample_bytree': 0.9017737678292055, 'gamma': 13.353870795267031, 'learning_rate': 0.0023821975392908853, 'max_depth': 7, 'min_child_weight': 48.67286949880866, 'n_estimators': 1999, 'reg_lambda': 12.87265579735746, 'subsample': 0.9095317569308281}
# Roc-AUC actual; 0.8877798148947418
# Con grid: {'colsample_bytree': 0.8392778142449405, 'gamma': 10.653641979349672, 'learning_rate': 0.00943050339551245, 'max_depth': 4, 'min_child_weight': 41.08184488552358, 'n_estimators': 2399, 'reg_lambda': 4.71091192489098, 'subsample': 0.6271609905891584}
# Roc-AUC actual; 0.8886428582324957
# Con grid: {'colsample_bytree': 0.9367392867050114, 'gamma': 13.19732870927543, 'learning_rate': 0.015763047376370784, 'max_depth': 7, 'min_child_weight': 5.647160420558678, 'n_estimators': 1741, 'reg_lambda': 1.509562177853, 'subsample': 0.6199370563779724}
# Roc-AUC actual; 0.8941937117143504
# Con grid: {'colsample_bytree': 0.6996901964163479, 'gamma': 5.2191211737325, 'learning_rate': 0.013510529367162379, 'max_depth': 11, 'min_child_weight': 21.775272719907967, 'n_estimators': 1395, 'reg_lambda': 5.2856241991448165, 'subsample': 0.9207237765423799}
# Roc-AUC actual; 0.8853168896946615
# Con grid: {'colsample_bytree': 0.8149505085893576, 'gamma': 14.686574070227318, 'learning_rate': 0.019024264148872105, 'max_depth': 6, 'min_child_weight': 36.96473675823866, 'n_estimators': 2453, 'reg_lambda': 4.876560231475485, 'subsample': 0.8431635983430488}
# Roc-AUC actual; 0.8894177317548914
# Con grid: {'colsample_bytree': 0.674374401856842, 'gamma': 2.6232215576393907, 'learning_rate': 0.02567211776717359, 'max_depth': 3, 'min_child_weight': 41.852056262147, 'n_estimators': 1354, 'reg_lambda': 1.1561701792719103, 'subsample': 0.6701900463333375}
# Roc-AUC actual; 0.896673427138695
# Con grid: {'colsample_bytree': 0.9532352799879698, 'gamma': 3.2329480318699777, 'learning_rate': 0.010811334597910427, 'max_depth': 7, 'min_child_weight': 1.659467728121311, 'n_estimators': 2152, 'reg_lambda': 6.124595141391767, 'subsample': 0.8796243665304214}
# Roc-AUC actual; 0.8918372284369241
# Con grid: {'colsample_bytree': 0.9662627455213784, 'gamma': 3.4914472065193314, 'learning_rate': 0.02422188091019854, 'max_depth': 4, 'min_child_weight': 32.53842737793737, 'n_estimators': 1145, 'reg_lambda': 10.060984678587511, 'subsample': 0.78022031549022}
# Roc-AUC actual; 0.8894274819222285
# Con grid: {'colsample_bytree': 0.6888463142247184, 'gamma': 6.705833157096381, 'learning_rate': 0.013810748136057788, 'max_depth': 6, 'min_child_weight': 19.080596993360004, 'n_estimators': 1201, 'reg_lambda': 5.706008234556145, 'subsample': 0.9884001642553297}
# Roc-AUC actual; 0.8841627520182402
# Con grid: {'colsample_bytree': 0.6887522076642105, 'gamma': 6.338226424679169, 'learning_rate': 0.0012607402551421587, 'max_depth': 10, 'min_child_weight': 1.358750804542208, 'n_estimators': 1113, 'reg_lambda': 4.200559943257342, 'subsample': 0.9291708383995605}

# %% [markdown]
# me quedo con el mejor auc

# %%
print('ROC-AUC: %0.5f' % best_score)
print('Grilla:', best_grid)
print(f'Tiempo transcurrido: {str(end - start)} segundos')
print(f'Tiempo de entrenamiento por iteración: {str(round((end - start) / iterations, 2))} segundos')
# Out:
# ROC-AUC: 0.89728
# Grilla: {'colsample_bytree': 0.6992999571329299, 'gamma': 2.6458047975933496, 'learning_rate': 0.014951033182184392, 'max_depth': 8, 'min_child_weight': 1.6939580123297493, 'n_estimators': 1684, 'reg_lambda': 5.435908486749497, 'subsample': 0.7902941751390218}
# Tiempo transcurrido: 22536.81769824028 segundos
# Tiempo de entrenamiento por iteración: 75.12 segundos

# %% [markdown]
# ahora con toda la data el prosible auc:

# %%
y_pred = best_estimator.predict_proba(X_val)[:, 1]
auc_roc = sklearn.metrics.roc_auc_score(y_val, y_pred)
print('AUC-ROC test: %0.5f' % auc_roc)
# Out:
# AUC-ROC test: 0.89728

# %% [markdown]
# entreno con toda la data train+val

# %%
# best_grid = {'colsample_bytree': 0.7860370513913187, 'gamma': 4.070235476608438, 'learning_rate': 0.02486212527455788, 'max_depth': 11, 'min_child_weight': 14.046725484369038, 'n_estimators': 879, 'reg_lambda': 4.1399877303381505, 'subsample': 0.6481367528520412}

# %%
clf_xgb = xgb.XGBClassifier(objective = 'binary:logistic', seed = random_state, eval_metric = 'auc', **best_grid,tree_method = 'gpu_hist') #enable_categorical = True
clf_xgb.fit(X_train_all, y_train_all, verbose = False)
final_model = clf_xgb

# %%
y_pred_submi = final_model.predict_proba(eval_data.drop(columns=["conversion", "ROW_ID"]))[:, 1]

# %% [markdown]
# ## Submission

# %%
# y_preds = cls.predict_proba(eval_data.drop(columns=["ROW_ID"]))[:, cls.classes_ == 1].squeeze()
# Make the submission file
submission_df = pd.DataFrame({"ROW_ID": eval_data["ROW_ID"], "conversion": y_pred_submi})
submission_df["ROW_ID"] = submission_df["ROW_ID"].astype(int)
submission_df.to_csv("mimir.csv", sep=",", index=False)
